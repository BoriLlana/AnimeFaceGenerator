# %%
import torch     # PyTorch
import datasets  # Huggingface Datasets; actual data

from IPython.display import display

# %%
dataset = datasets.load_dataset("DrishtiSharma/Anime-Face-Dataset")
# Out:
# Found cached dataset parquet (C:/Users/Timothy/.cache/huggingface/datasets/DrishtiSharma___parquet/DrishtiSharma--Anime-Face-Dataset-1886e0ceeb6ab6bb/0.0.0/2a3b91fbd88a2c90d1dbbb32b460cf621d31bd5b05b934492fdef7d8d6f236ec)
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
print(dataset.shape) 
display( dataset['train'][69]['image'], dataset['train'][1]['image'] )
# Out:
# {'train': (63565, 1)}
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=63x63>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=62x62>

# %%
import glob
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline


images = []
for i in range(0,5):
    images.append(  dataset['train'][i]['image']  )

plt.figure(figsize=(20,10))
columns = 5
for i, image in enumerate(images):
    plt.subplot(len(images) / columns + 1, columns, i + 1)
    plt.imshow(image)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[14], line 9
#       7 images = []
#       8 for i in range(0,5):
# ----> 9     images.append( mpimg.imread( dataset['train'][i]['image'] ) )
#      11 plt.figure(figsize=(20,10))
#      12 columns = 5
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\image.py:1541, in imread(fname, format)
#    1534 if isinstance(fname, str) and len(parse.urlparse(fname).scheme) > 1:
#    1535     # Pillow doesn't handle URLs directly.
#    1536     raise ValueError(
#    1537         "Please open the URL for reading and pass the "
#    1538         "result to Pillow, e.g. with "
#    1539         "``np.array(PIL.Image.open(urllib.request.urlopen(url)))``."
#    1540         )
# -> 1541 with img_open(fname) as image:
#    1542     return (_pil_png_to_float_array(image)
#    1543             if isinstance(image, PIL.PngImagePlugin.PngImageFile) else
#    1544             pil_to_array(image))
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\PIL\ImageFile.py:117, in ImageFile.__init__(self, fp, filename)
#     115 try:
#     116     try:
# --> 117         self._open()
#     118     except (
#     119         IndexError,  # end of data
#     120         TypeError,  # end of data (ord)
#    (...)
#     123         struct.error,
#     124     ) as v:
#     125         raise SyntaxError(v) from v
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\PIL\PngImagePlugin.py:730, in PngImageFile._open(self)
#     728 def _open(self):
# --> 730     if not _accept(self.fp.read(8)):
#     731         msg = "not a PNG file"
#     732         raise SyntaxError(msg)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\PIL\Image.py:529, in Image.__getattr__(self, name)
#     527     deprecate("Image categories", 10, "is_animated", plural=True)
#     528     return self._category
# --> 529 raise AttributeError(name)
#
# AttributeError: read
